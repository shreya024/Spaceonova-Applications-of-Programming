# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya024/Spaceonova-Applications-of-Programming/blob/main/Day4/SV_604.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 4

# %% [markdown]
# ### Q1. Create an RGB image of M74 galaxy combining the images of u,g and i filter from the link given below.

# %% [markdown]
# https://dr12.sdss.org/fields

# %%
from astropy.visualization import make_lupton_rgb
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
g=fits.getdata('/content/sample_data/frame-g-007845-2-0104.fits')
r=fits.getdata('/content/sample_data/frame-i-007845-2-0104.fits')
b=fits.getdata('/content/sample_data/frame-u-006073-4-0063.fits')
plt.figure()
plt.imshow(make_lupton_rgb(r,g,b))

# %% [markdown]
# ### Q2. Download any of your favourite images of SPACE in FITS format and write the following information into the FITS file.

# %% [markdown]
# OBSERVER= 'Your name'
# DATE    = '20-11-2021'
# AUTHOR  = 'Spaceonova'
# MESSAGE = 'Any message you would like to give to Spaceonova'

# %%
from astropy.utils.data import download_file

# %%
image_file=download_file('http://www.astropy.org/astropy-data/tutorials/FITS-images/HorseHead.fits')

# %%
hn=fits.open(image_file)

# %%
fits.setval(image_file,'OBSERVER',value='Shreya Ghosh')
fits.setval(image_file,'DATE',value='20-11-2021')
fits.setval(image_file,'AUTHOR',value='Spaceonova')
fits.setval(image_file,'MESSAGE',value='Loved the Amazing Sessions by Spaceonova')

# %%
hn=fits.open(image_file)
hn[0].header
# Out:
# SIMPLE  =                    T /FITS: Compliance
# BITPIX  =                   16 /FITS: I*2 Data
# NAXIS   =                    2 /FITS: 2-D Image Data
# NAXIS1  =                  891 /FITS: X Dimension
# NAXIS2  =                  893 /FITS: Y Dimension
# EXTEND  =                    T /FITS: File can contain extensions
# DATE    = '20-11-2021'         / FITS: Creation Date
# ORIGIN  = 'STScI/MAST'         /GSSS: STScI Digitized Sky Survey
# SURVEY  = 'SERC-ER '           /GSSS: Sky Survey
# REGION  = 'ER768   '           /GSSS: Region Name
# PLATEID = 'A0JP    '           /GSSS: Plate ID
# SCANNUM = '01      '           /GSSS: Scan Number
# DSCNDNUM= '00      '           /GSSS: Descendant Number
# TELESCID=                    4 /GSSS: Telescope ID
# BANDPASS=                   36 /GSSS: Bandpass Code
# COPYRGHT= 'AAO/ROE '           /GSSS: Copyright Holder
# SITELAT =              -31.277 /Observatory: Latitude
# SITELONG=              210.934 /Observatory: Longitude
# ...
